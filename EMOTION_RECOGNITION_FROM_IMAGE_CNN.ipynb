# %%
import cv2 #computer vision

# %%
img=cv2.imread("/content/baby crying.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #bgr

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) #RGB

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 18.5 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=49858bdedcad2133d7a16c932aa9c845a53dd59e6f8dd5fa1fba941b76b32288
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
from deepface import DeepFace
pred=DeepFace.analyze(img)
# Out:
# 24-09-10 14:15:42 - Directory /root/.deepface has been created
# 24-09-10 14:15:42 - Directory /root/.deepface/weights has been created
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-09-10 14:15:44 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 69.5MB/s]
# Action: age:  25%|██▌       | 1/4 [00:00<00:02,  1.19it/s]    Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 24-09-10 14:15:47 - age_model_weights.h5 will be downloaded...
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   2%|▏         | 10.5M/539M [00:00<00:05, 105MB/s]
#   8%|▊         | 41.4M/539M [00:00<00:02, 223MB/s]
# ...

# %%
type(pred)
pred
# Out:
# [{'emotion': {'angry': 0.001434747719031293,
#    'disgust': 9.185615809648162e-10,
#    'fear': 39.52079713344574,
#    'happy': 0.044839546899311244,
#    'sad': 60.337090492248535,
#    'surprise': 9.767813935468439e-06,
#    'neutral': 0.09583064238540828},
#   'dominant_emotion': 'sad',
#   'region': {'x': 236,
#    'y': 505,
#    'w': 534,
#    'h': 534,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.95,
#   'age': 21,
#   'gender': {'Woman': 11.119073629379272, 'Man': 88.8809323310852},
#   'dominant_gender': 'Man',
#   'race': {'asian': 4.919382850490979,
#    'indian': 2.1210315970201252,
#    'black': 0.23812483087181036,
#    'white': 35.61593506431193,
#    'middle eastern': 11.163309881884448,
#    'latino hispanic': 45.94221984995722},
#   'dominant_race': 'latino hispanic'}]

# %%
prediction=pred[0]
prediction["dominant_emotion"]
# Out:
# 'sad'
